# %%
import os

# %%
filename = os.path.join('data','03_Prod.mdout')
f = open(filename,'r')
data = f.readlines()
f.close()

newfile = open('Etot.txt','w+')

for line in data:
    splitline = line.split()
    if 'Etot' in line:
        newfile.write(f'splitline[2] \n')
        
        
    newfile.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-9095c25c246d> in <module>
#       9     splitline = line.split()
#      10     if 'Etot' in line:
# ---> 11         newfile.write(f'splitline[2] \n')
#      12
#      13
#
# ValueError: I/O operation on closed file.

# %%
for line in data:
    if'Etot'in line:
# Out:
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# was
# ...
